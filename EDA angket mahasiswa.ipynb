# %%
# %matplotlib inline
import matplotlib
import numpy as np                  
import pandas as pd                 
import matplotlib.pyplot as plt     
from matplotlib import rc
import seaborn as sns
from datetime import datetime, date
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

sns.set_theme(style="whitegrid")

custom_cmap = LinearSegmentedColormap.from_list('custom_camp', ['#f07167', '#0096c7'], N=100)
custom_cmap2 = LinearSegmentedColormap.from_list('custom_camp2', ['#505484', '#489c9c'], N=100)

colors = ["#0096c7", "#f07167", "#1ac938"]

custom_palette1 = sns.set_palette(sns.color_palette(colors))

colors2 = ['#495084']
cus_col = sns.color_palette(colors2)

title = 'angket'

print('matplotlib: {}'.format(matplotlib.__version__))
# Out:
# matplotlib: 3.6.1

# %%
# membaca data
df = pd.read_csv("C:\\Users\\sudir\\OneDrive\\Documents\\Data analyst\angket_mhs.csv")
df.head(5)
# Out:
#                  Nama      NIM  Program Studi  Keandalan  Daya tanggap  \
# 0         Rifqi Fajar  2101103  Ilmu Komputer          7             7
# 1  Rasyid Andriansyah  2101963  Ilmu Komputer          8             8
# 2  Apri Anggara Yudha  2102585  Ilmu Komputer          7             8
# 3  Ayesha Ali Firdaus  2101990  Ilmu Komputer          7             8
# 4       Afif Alfauzan  1801527  Ilmu Komputer          8             8
#
#    Kepastian  Empati  Tangible
# 0          7       8         8
# 1          8       8         8
# 2          6       6         8
# 3          8       8         8
# 4          7       8         7

# %%
# cek data yang kosong
df.isnull().sum()
# Out:
# Nama             0
# NIM              0
# Program Studi    0
# Keandalan        0
# Daya tanggap     0
# Kepastian        0
# Empati           0
# Tangible         0
# dtype: int64

# %%
# mengcek data ganda
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Jumlah angket berdasakan Program studi

# %%
plt.figure(figsize=(5, 4))

y = 'Program Studi'

g = sns.countplot(x="Program Studi", data = df, palette="deep")
g.set(ylabel=f'Jumlah {title}', xlabel=f'{y}')
plt.suptitle(f"Jumlah {title} Berdasarkan {y}" , fontsize = 'x-large', fontweight = 'regular', y=1)

for container in g.containers:
    g.bar_label(container, padding=4)

# %% [raw]
# Data di atas menunjukan jumlah responden dari program studi ilmu komputer lebih banyak dari program studi pendidikan ilmu komputer.

# %% [markdown]
# ## Jumlah angket berdasarkan tingkat keandalan

# %%
plt.figure(figsize=(8, 4))

y = 'Keandalan'

g = sns.countplot(x="Keandalan", data = df, palette="deep")
g.set(ylabel=f'Jumlah {title}', xlabel=f'{y}')
plt.suptitle(f"Jumlah {title} Berdasarkan {y}" , fontsize = 'x-large', fontweight = 'regular', y=1)

for container in g.containers:
    g.bar_label(container, padding=4)

# %% [raw]
# Data di atas menunjukan bahwa mahasiswa memiliki keandalan yang tinggi. tingkat keandalan terbanyak terdapat pada tingkatan 8.

# %% [markdown]
# ## Jumlah angket berdasarkan tingkat daya tanggap

# %%
plt.figure(figsize=(8, 4))

y = 'Daya tanggap'

g = sns.countplot(x="Daya tanggap", data = df, palette="deep")
g.set(ylabel=f'Jumlah {title}', xlabel=f'{y} ')
plt.suptitle(f"Jumlah {title} Berdasarkan {y}" , fontsize = 'x-large', fontweight = 'regular', y=1)

for container in g.containers:
    g.bar_label(container, padding=4)

# %% [raw]
# Berdasarkan grafik diatas tingkat daya tanggap mahasiswa miliki tingkatan yang tinggi.

# %% [markdown]
# ## Jumlah angket berdasarkan tingkat kepastian

# %%
plt.figure(figsize=(8, 4))

y = 'Kepastian'

g = sns.countplot(x="Kepastian", data = df, palette="deep")
g.set(ylabel=f'Jumlah {title}', xlabel=f'{y} ')
plt.suptitle(f"Jumlah {title} Berdasarkan {y}" , fontsize = 'x-large', fontweight = 'regular', y=1)

for container in g.containers:
    g.bar_label(container, padding=4)

# %%
Berdasarkan data di atas tingkat kepastian mahasiswa memiliki tingkatan yang cukup tinggi.

# %% [markdown]
# ## Jumlah angket berdasarkan tingkat empati

# %%
plt.figure(figsize=(8, 4))

y = 'Empati'

g = sns.countplot(x="Empati", data = df, palette="deep")
g.set(ylabel=f'Jumlah {title}', xlabel=f'{y} ')
plt.suptitle(f"Jumlah {title} Berdasarkan {y}" , fontsize = 'x-large', fontweight = 'regular', y=1)

for container in g.containers:
    g.bar_label(container, padding=4)

# %% [raw]
# Data di atas menunjukan data angket mahasiswa dengan tingkatan empati.

# %% [markdown]
# ## Jumlah angket berdasarkan tingkat tangible

# %%
plt.figure(figsize=(8, 4))

y = 'Tangible'

g = sns.countplot(x="Tangible", data = df,  palette="deep")
g.set(ylabel=f'Jumlah {title}', xlabel=f'{y} ')
plt.suptitle(f"Jumlah {title} Berdasarkan {y}" , fontsize = 'x-large', fontweight = 'regular', y=1)

for container in g.containers:
    g.bar_label(container, padding=4)

# %% [raw]
# Data di atas menjukan tingkatan tangible yang sangat tinggi.
